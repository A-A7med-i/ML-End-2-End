# %%
import sys

sys.path.append("../")

# %%
from script.configuration import DATA_PATH

# %%
from script.dataframe_summary_utils import DataFrameSummary

# %%
import pandas as pd

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.head(2)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S

# %%
df_summary = DataFrameSummary(df)

# %%
df_summary.generate_dataframe_summary()
# Out:
#                    Data Type     Min       Max         Std        Mean  \
# work_year              int64    2020      2023       0.691    2022.374
# experience_level      object  No Min    No Max      No Std     No Mean
# employment_type       object  No Min    No Max      No Std     No Mean
# job_title             object  No Min    No Max      No Std     No Mean
# salary                 int64    6000  30400000  671676.501  190695.572
# salary_currency       object  No Min    No Max      No Std     No Mean
# salary_in_usd          int64    5132    450000   63055.625   137570.39
# employee_residence    object  No Min    No Max      No Std     No Mean
# remote_ratio           int64       0       100      48.589      46.272
# company_location      object  No Min    No Max      No Std     No Mean
# company_size          object  No Min    No Max      No Std     No Mean
#
#                        Median  Unique Values  Nulls
# work_year              2022.0              4      0
# experience_level    No Median              4      0
# employment_type     No Median              4      0
# job_title           No Median             93      0
# salary               138000.0            815      0
# salary_currency     No Median             20      0
# salary_in_usd        135000.0           1035      0
# employee_residence  No Median             78      0
# remote_ratio              0.0              3      0
# company_location    No Median             72      0
# company_size        No Median              3      0
